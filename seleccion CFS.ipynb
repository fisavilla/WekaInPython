# %%
import weka.core.jvm as jvm
jvm.start()
help(jvm.start)
help(jvm.stop)
# Out:
# INFO:weka.core.jvm:JVM already running, call jvm.stop() first
# Help on function start in module weka.core.jvm:
#
# start(class_path=None, bundled=True, packages=False, system_cp=False, max_heap_size=None, system_info=False)
#     Initializes the javabridge connection (starts up the JVM).
#
#     :param class_path: the additional classpath elements to add
#     :type class_path: list
#     :param bundled: whether to add jars from the "lib" directory
#     :type bundled: bool
#     :param packages: whether to add jars from Weka packages as well (bool) or an alternative Weka home directory (str)
#     :type packages: bool or str
#     :param system_cp: whether to add the system classpath as well
#     :type system_cp: bool
#     :param max_heap_size: the maximum heap size (-Xmx parameter, eg 512m or 4g)
#     :type max_heap_size: str
#     :param system_info: whether to print the system info (generated by weka.core.SystemInfo)
#     :type system_info: bool
#
# Help on function stop in module weka.core.jvm:
#
# stop()
#     Kills the JVM.

# %%
import os
import traceback
import weka.core.jvm as jvm
import wekaexamples.helper as helper
from weka.core.converters import Loader
from weka.attribute_selection import ASSearch
from weka.attribute_selection import ASEvaluation
from weka.attribute_selection import AttributeSelection

    
    # load a dataset
datasrc="C:\Users\Fidelina Villa\Documents\\train\\SMOTE\\"
nameFile="Train.arff"
helper.print_info("Loading dataset: " + datasrc+nameFile)
loader = Loader("weka.core.converters.ArffLoader")
anneal_data = loader.load_file(datasrc+nameFile)
anneal_data.class_is_last()

    # perform attribute selection
helper.print_title("Attribute selection")
search = ASSearch(classname="weka.attributeSelection.BestFirst", options=["-D", "1", "-N", "5"])
evaluation = ASEvaluation(classname="weka.attributeSelection.CfsSubsetEval", options=["-P", "1", "-E", "1"])
attsel = AttributeSelection()
attsel.search(search)
attsel.evaluator(evaluation)
attsel.select_attributes(anneal_data)
print("# attributes: " + str(attsel.number_attributes_selected))
print("attributes (as numpy array): " + str(attsel.selected_attributes))
print("attributes (as list): " + str(list(attsel.selected_attributes)))
print("result string:\n" + attsel.results_string)

# perform ranking
helper.print_title("Attribute ranking (2-fold CV)")
search = ASSearch(classname="weka.attributeSelection.Ranker", options=["-N", "-1"])
evaluation = ASEvaluation("weka.attributeSelection.InfoGainAttributeEval")
attsel = AttributeSelection()
attsel.ranking(True)
attsel.folds(2)
attsel.crossvalidation(True)
attsel.seed(42)
attsel.search(search)
attsel.evaluator(evaluation)
attsel.select_attributes(anneal_data)
print("ranked attributes:\n" + str(attsel.ranked_attributes))
print("result string:\n" + attsel.results_string)
# Out:
# Loading dataset: C:\Users\Fidelina Villa\Documents\train\SMOTE\Train.arff
#
# Attribute selection
# ===================
# # attributes: 14
# attributes (as numpy array): [ 5 12 18 22 23 27 30 42 43 44 46 47 57 58 59]
# attributes (as list): [5, 12, 18, 22, 23, 27, 30, 42, 43, 44, 46, 47, 57, 58, 59]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Best first.
# 	Start set: no attributes
# 	Search direction: forward
# 	Stale search after 5 node expansions
# 	Total number of subsets evaluated: 959
# 	Merit of best subset found:    0.276
#
# Attribute Subset Evaluator (supervised, Class (nominal): 60 Class):
# 	CFS Subset Evaluator
# 	Including locally predictive attributes
#
# Selected attributes: 6,13,19,23,24,28,31,43,44,45,47,48,58,59 : 14
#                      ITEP
#                      ModalidaddeContratacion
#                      Plazocontrato
#                      DocumentoProveedor
#                      ProveedorAdjudicado
#                      Municipio2
#                      HabilitaPagoAdelantado
#                      ValorPendientedeEjecucion
#                      SaldoCDP
#                      SaldoVigencia
#                      DestinoGasto
#                      OrigendelosRecursos
#                      NumcategoriasEntidad
#                      contratosporproveedor
#
#
# Attribute ranking (2-fold CV)
# =============================
# ranked attributes:
# [[2.30000000e+01 8.99182804e-01]
#  [2.50000000e+01 8.16347496e-01]
#  [1.50000000e+01 7.72391377e-01]
#  [1.40000000e+01 7.38618328e-01]
#  [1.30000000e+01 6.81872884e-01]
#  [1.70000000e+01 5.42208198e-01]
#  [1.60000000e+01 5.21730735e-01]
#  [0.00000000e+00 3.94022876e-01]
#  [2.70000000e+01 3.73785705e-01]
#  [1.00000000e+01 2.93408463e-01]
#  [2.60000000e+01 2.89626777e-01]
#  [5.70000000e+01 2.88925586e-01]
#  [2.20000000e+01 2.55032465e-01]
#  [4.30000000e+01 2.14387468e-01]
#  [5.80000000e+01 1.94508371e-01]
#  [4.20000000e+01 1.65824169e-01]
#  [3.80000000e+01 1.59134759e-01]
#  [3.50000000e+01 1.56026738e-01]
#  [5.00000000e+00 1.29638629e-01]
#  [1.80000000e+01 1.27926907e-01]
#  [2.00000000e+01 1.24592637e-01]
#  [6.00000000e+00 1.23119573e-01]
#  [9.00000000e+00 1.16526160e-01]
#  [1.90000000e+01 1.05535233e-01]
#  [2.00000000e+00 5.99705095e-02]
#  [1.20000000e+01 5.64763995e-02]
#  [8.00000000e+00 5.45871545e-02]
#  [2.40000000e+01 5.37928558e-02]
#  [4.80000000e+01 4.57173037e-02]
#  [1.00000000e+00 4.47049831e-02]
#  [2.90000000e+01 3.98632245e-02]
#  [4.70000000e+01 3.93592143e-02]
#  [4.40000000e+01 3.83903304e-02]
#  [3.00000000e+01 2.86938567e-02]
#  [4.60000000e+01 2.60693049e-02]
#  [3.20000000e+01 1.85126185e-02]
#  [7.00000000e+00 1.52113636e-02]
#  [4.10000000e+01 1.21153878e-02]
#  [5.60000000e+01 1.14215159e-02]
#  [3.10000000e+01 9.87153533e-03]
#  [2.10000000e+01 8.38748686e-03]
#  [3.70000000e+01 7.31774501e-03]
#  [4.00000000e+00 2.48960858e-03]
#  [4.50000000e+01 8.07783598e-04]
#  [3.30000000e+01 7.18273282e-04]
#  [4.90000000e+01 4.03727750e-04]
#  [5.00000000e+01 4.03727750e-04]
#  [2.80000000e+01 6.47116572e-06]
#  [4.00000000e+01 0.00000000e+00]
#  [3.90000000e+01 0.00000000e+00]
#  [3.00000000e+00 0.00000000e+00]
#  [5.10000000e+01 0.00000000e+00]
#  [5.20000000e+01 0.00000000e+00]
#  [5.40000000e+01 0.00000000e+00]
#  [5.30000000e+01 0.00000000e+00]
#  [5.50000000e+01 0.00000000e+00]
#  [3.40000000e+01 0.00000000e+00]
#  [1.10000000e+01 0.00000000e+00]
#  [3.60000000e+01 0.00000000e+00]]
# result string:
#
#
# === Attribute Selection on all input data ===
#
# Search Method:
# 	Attribute ranking.
#
# Attribute Evaluator (supervised, Class (nominal): 60 Class):
# 	Information Gain Ranking Filter
#
# Ranked attributes:
#  0.8991828     24 ProveedorAdjudicado
#  0.8163475     26 Fechadecreacion
#  0.77239138    16 FechadeFindelContrato
#  0.73861833    15 FechadeIniciodelContrato
#  0.68187288    14 FechadeFirma
#  0.5422082     18 FechadeFindeEjecucion
#  0.52173074    17 FechadeIniciodeEjecucion
#  0.39402288     1 NombreEntidad
#  0.3737857     28 Municipio2
#  0.29340846    11 CodigodeCategoriaPrincipal
#  0.28962678    27 Departamento2
#  0.28892559    58 NumcategoriasEntidad
#  0.25503247    23 DocumentoProveedor
#  0.21438747    44 SaldoCDP
#  0.19450837    59 contratosporproveedor
#  0.16582417    43 ValorPendientedeEjecucion
#  0.15913476    39 ValorPendientedePago
#  0.15602674    36 ValordelContrato
#  0.12963863     6 ITEP
#  0.12792691    19 Plazocontrato
#  0.12459264    21 Tiempodemora
#  0.12311957     7 Sector
#  0.11652616    10 EstadoContrato
#  0.10553523    20 Plazodeejecucion
#  0.05997051     3 Ciudad
#  0.0564764     13 ModalidaddeContratacion
#  0.05458715     9 EntidadCentralizada
#  0.05379286    25 Tipodeempresa
#  0.0457173     49 DiasAdicionados
#  0.04470498     2 Departamento
#  0.03986322    30 EsPyme
#  0.03935921    48 OrigendelosRecursos
#  0.03839033    45 SaldoVigencia
#  0.02869386    31 HabilitaPagoAdelantado
#  0.0260693     47 DestinoGasto
#  0.01851262    33 ObligacionAmbiental
#  0.01521136     8 Rama
#  0.01211539    42 ValorPendientedeAmortizacion
#  0.01142152    57 RecursosPropios
#  0.00987154    32 Liquidacion
#  0.00838749    22 CondicionesdeEntrega
#  0.00731775    38 ValorFacturado
#  0.00248961     5 Orden
#  0.00080778    46 EsPostConflicto
#  0.00071827    34 ObligacionesPostconsumo
#  0.00040373    50 PuntosdelAcuerdo
#  0.00040373    51 PilaresdelAcuerdo
#  0.00000647    29 EsGrupo
#  0             41 ValorAmortizado
#  0             40 ValorPagado
#  0              4 Localizacion
#  0             52 PresupuestoGeneraldelaNacion?PGN
#  0             53 SistemaGeneraldeParticipaciones
#  0             55 RecursosPropios(AlcaldiasGobernacionesyResguardosIndigenas)
#  0             54 SistemaGeneraldeRegalias
#  0             56 RecursosdeCredito
#  0             35 Reversion
#  0             12 TipodeContrato
#  0             37 Valordepagoadelantado
#
# Selected attributes: 24,26,16,15,14,18,17,1,28,11,27,58,23,44,59,43,39,36,6,19,21,7,10,20,3,13,9,25,49,2,30,48,45,31,47,33,8,42,57,32,22,38,5,46,34,50,51,29,41,40,4,52,53,55,54,56,35,12,37 : 59
#
#
# === Attribute selection 2 fold cross-validation (stratified), seed: 42 ===
#
# average merit      average rank  attribute
#  0.91  +- 0.002       1   +- 0        24 ProveedorAdjudicado
#  0.837 +- 0.002       2   +- 0        26 Fechadecreacion
#  0.784 +- 0.007       3   +- 0        16 FechadeFindelContrato
#  0.75  +- 0.001       4   +- 0        15 FechadeIniciodelContrato
#  0.694 +- 0.008       5   +- 0        14 FechadeFirma
#  0.546 +- 0.016       6   +- 0        18 FechadeFindeEjecucion
#  0.527 +- 0.001       7   +- 0        17 FechadeIniciodeEjecucion
#  0.384 +- 0.041       8.5 +- 0.5      28 Municipio2
#  0.405 +- 0.006       8.5 +- 0.5       1 NombreEntidad
#  0.297 +- 0.002      10.5 +- 0.5      11 CodigodeCategoriaPrincipal
#  0.299 +- 0.046      10.5 +- 0.5      27 Departamento2
#  0.219 +- 0          13   +- 1        44 SaldoCDP
#  0.165 +- 0          14.5 +- 1.5      43 ValorPendientedeEjecucion
#  0.177 +- 0.027      15   +- 0        59 contratosporproveedor
#  0.146 +- 0.009      16   +- 2        39 ValorPendientedePago
#  0.148 +- 0.016      17   +- 0        36 ValordelContrato
#  0.16  +- 0.065      17.5 +- 4.5      58 NumcategoriasEntidad
#  0.131 +- 0.002      18.5 +- 0.5       6 ITEP
#  0.129 +- 0.009      18.5 +- 2.5       7 Sector
#  0.123 +- 0.002      20   +- 0        21 Tiempodemora
#  0.117 +- 0.006      21   +- 2        10 EstadoContrato
#  0.108 +- 0.002      22.5 +- 1.5      20 Plazodeejecucion
#  0.095 +- 0.022      22.5 +- 0.5      19 Plazocontrato
#  0.131 +- 0.096      22.5 +-10.5      23 DocumentoProveedor
#  0.062 +- 0.002      24.5 +- 0.5       3 Ciudad
#  0.057 +- 0.003      26   +- 1        13 ModalidaddeContratacion
#  0.055 +- 0.002      27   +- 1        25 Tipodeempresa
#  0.055 +- 0.005      27   +- 1         9 EntidadCentralizada
#  0.046 +- 0.004      29   +- 0         2 Departamento
#  0.042 +- 0.006      30.5 +- 0.5      45 SaldoVigencia
#  0.04  +- 0          31   +- 1        49 DiasAdicionados
#  0.042 +- 0.017      31   +- 4        30 EsPyme
#  0.039 +- 0.005      31.5 +- 0.5      48 OrigendelosRecursos
#  0.03  +- 0.001      33.5 +- 0.5      31 HabilitaPagoAdelantado
#  0.027 +- 0.001      34.5 +- 0.5      47 DestinoGasto
#  0.019 +- 0.001      36.5 +- 0.5      33 ObligacionAmbiental
#  0.017 +- 0.001      37.5 +- 0.5       8 Rama
#  0.011 +- 0.006      39.5 +- 1.5      32 Liquidacion
#  0.009 +- 0.001      39.5 +- 0.5      22 CondicionesdeEntrega
#  0.003 +- 0.001      41.5 +- 1.5       5 Orden
#  0.008 +- 0.008      41.5 +- 2.5      42 ValorPendientedeAmortizacion
#  0.001 +- 0          42.5 +- 1.5      46 EsPostConflicto
#  0.001 +- 0.001      42.5 +- 0.5      34 ObligacionesPostconsumo
#  0     +- 0          44.5 +- 2.5      29 EsGrupo
#  0.009 +- 0.009      46   +-10        57 RecursosPropios
#  0     +- 0          47.5 +- 2.5      50 PuntosdelAcuerdo
#  0     +- 0          49   +- 1         4 Localizacion
#  0     +- 0          50   +- 1        41 ValorAmortizado
#  0     +- 0          50   +- 1        35 Reversion
#  0     +- 0          50   +- 4        40 ValorPagado
#  0     +- 0          51   +- 6        38 ValorFacturado
#  0     +- 0          51.5 +- 4.5      37 Valordepagoadelantado
#  0     +- 0          52   +- 6        51 PilaresdelAcuerdo
#  0     +- 0          52.5 +- 0.5      52 PresupuestoGeneraldelaNacion?PGN
#  0     +- 0          53.5 +- 5.5      12 TipodeContrato
#  0     +- 0          53.5 +- 0.5      53 SistemaGeneraldeParticipaciones
#  0     +- 0          53.5 +- 1.5      54 SistemaGeneraldeRegalias
#  0     +- 0          57   +- 2        55 RecursosPropios(AlcaldiasGobernacionesyResguardosIndigenas)
#  0     +- 0          57.5 +- 0.5      56 RecursosdeCredito

# %%
REMOVIENDO VARIABLES

# %%
import os
import traceback
import weka.core.jvm as jvm
import wekaexamples.helper as helper
from weka.core.converters import Loader
from weka.core.stemmers import Stemmer
from weka.core.stopwords import Stopwords
from weka.core.tokenizers import Tokenizer
from weka.filters import Filter, MultiFilter, StringToWordVector


datasrc="C:\Users\Fidelina Villa\Documents\\train\\SMOTE\\"
nameFile="Train2.arff"
helper.print_info("Loading dataset: " + datasrc+nameFile)
loader = Loader("weka.core.converters.ArffLoader")
data = loader.load_file(datasrc+nameFile)

nameFile="Test2.arff"
helper.print_info("Loading dataset: " + datasrc+nameFile)
loader = Loader("weka.core.converters.ArffLoader")
data2 = loader.load_file(datasrc+nameFile)

# remove class attribute
helper.print_info("Removing class attribute")
remove = Filter(classname="weka.filters.unsupervised.attribute.Remove", options=["-V","-R", "5, 12, 18, 22, 23, 27, 30, 42, 43, 44, 46, 47, 57, 58, 59, last"])
remove.inputformat(data)
TrainCFS = remove.filter(data)
TestCFS = remove.filter(data2)
helper.print_info("Removed class attribute")
# Out:
# Loading dataset: C:\Users\Fidelina Villa\Documents\train\SMOTE\Train2.arff
#
# Loading dataset: C:\Users\Fidelina Villa\Documents\train\SMOTE\Test2.arff
#
# Removing class attribute
#
# Removed class attribute
